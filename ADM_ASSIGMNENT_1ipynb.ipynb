# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51510/DATAMINING/blob/main/ADM_ASSIGMNENT_1ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/employee_data.csv')
print("Original Dataset:")
print(df)
# Out:
# Original Dataset:
#     Employee_ID   Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  50.0  108953.0               9.0                   36
# 1          1002  36.0   82995.0               8.0                   59
# 2          1003  29.0   70757.0               2.0                   30
# 3          1004  42.0   39692.0               1.0                   30
# 4          1005  40.0   75758.0               7.0                   54
# 5          1006  44.0  102409.0               7.0                   56
# 6          1007  32.0       NaN               NaN                   59
# 7          1008  32.0   95697.0               5.0                   54
# 8          1009  45.0   67065.0               3.0                   49
# 9          1010  57.0       NaN               8.0                   42
# 10         1011  45.0   41534.0               6.0                   38
# 11         1012   NaN   70397.0               NaN                   32
# ...

# %%
df.isna()
# Out:
#     Employee_ID    Age  Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0         False  False   False             False                False
# 1         False  False   False             False                False
# 2         False  False   False             False                False
# 3         False  False   False             False                False
# 4         False  False   False             False                False
# 5         False  False   False             False                False
# 6         False  False    True              True                False
# 7         False  False   False             False                False
# 8         False  False   False             False                False
# 9         False  False    True             False                False
# 10        False  False   False             False                False
# 11        False   True   False              True                False
# ...

# %%
df.isnull().sum()
# Out:
# Employee_ID             0
# Age                     5
# Salary                  5
# Job_Satisfaction       10
# Work_Hours_Per_Week     0
# dtype: int64

# %%
df['Age'].mean()
# Out:
# 39.17777777777778

# %%
df['Salary'].mean()
# Out:
# 72349.2

# %%
df['Job_Satisfaction'].mean()
# Out:
# 5.55

# %%
df['Job_Satisfaction'].mode()
# Out:
# 0    7.0
# Name: Job_Satisfaction, dtype: float64

# %%
df['Job_Satisfaction'].median()
# Out:
# 6.0

# %%
df['Age'].fillna(df['Age'].mean())
# Out:
# 0     50.000000
# 1     36.000000
# 2     29.000000
# 3     42.000000
# 4     40.000000
# 5     44.000000
# 6     32.000000
# 7     32.000000
# 8     45.000000
# 9     57.000000
# 10    45.000000
# 11    39.177778
# 12    43.000000
# 13    23.000000
# 14    45.000000
# 15    51.000000
# 16    59.000000
# 17    23.000000
# 18    42.000000
# 19    54.000000
# 20    33.000000
# 21    43.000000
# 22    46.000000
# 23    48.000000
# 24    49.000000
# 25    37.000000
# 26    36.000000
# 27    24.000000
# 28    58.000000
# 29    28.000000
# 30    39.177778
# 31    30.000000
# 32    39.000000
# 33    25.000000
# 34    39.177778
# 35    35.000000
# 36    30.000000
# 37    47.000000
# 38    23.000000
# 39    39.177778
# 40    49.000000
# 41    28.000000
# 42    29.000000
# 43    56.000000
# 44    35.000000
# 45    38.000000
# 46    57.000000
# 47    25.000000
# 48    23.000000
# 49    39.177778
# Name: Age, dtype: float64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df
# Out:
#     Employee_ID        Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  50.000000  108953.0               9.0                   36
# 1          1002  36.000000   82995.0               8.0                   59
# 2          1003  29.000000   70757.0               2.0                   30
# 3          1004  42.000000   39692.0               1.0                   30
# 4          1005  40.000000   75758.0               7.0                   54
# 5          1006  44.000000  102409.0               7.0                   56
# 6          1007  32.000000       NaN               NaN                   59
# 7          1008  32.000000   95697.0               5.0                   54
# 8          1009  45.000000   67065.0               3.0                   49
# 9          1010  57.000000       NaN               8.0                   42
# 10         1011  45.000000   41534.0               6.0                   38
# ...

# %%
df['Work_Hours_Per_Week'].fillna(df['Work_Hours_Per_Week'].mean())
# Out:
# 0     36
# 1     59
# 2     30
# 3     30
# 4     54
# 5     56
# 6     59
# 7     54
# 8     49
# 9     42
# 10    38
# 11    32
# 12    36
# 13    35
# 14    37
# 15    56
# 16    38
# 17    59
# 18    34
# 19    30
# 20    48
# 21    39
# 22    41
# 23    53
# 24    44
# 25    56
# 26    51
# 27    53
# 28    38
# 29    49
# 30    46
# 31    59
# 32    46
# 33    55
# 34    49
# 35    41
# 36    59
# 37    36
# 38    31
# 39    32
# 40    46
# 41    34
# 42    46
# 43    53
# 44    46
# 45    56
# 46    46
# 47    31
# 48    31
# 49    57
# Name: Work_Hours_Per_Week, dtype: int64

# %%
print("Dataset after handling missing values:")
print(df)
# Out:
# Dataset after handling missing values:
#     Employee_ID        Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  50.000000  108953.0               9.0                   36
# 1          1002  36.000000   82995.0               8.0                   59
# 2          1003  29.000000   70757.0               2.0                   30
# 3          1004  42.000000   39692.0               1.0                   30
# 4          1005  40.000000   75758.0               7.0                   54
# 5          1006  44.000000  102409.0               7.0                   56
# 6          1007  32.000000       NaN               NaN                   59
# 7          1008  32.000000   95697.0               5.0                   54
# 8          1009  45.000000   67065.0               3.0                   49
# 9          1010  57.000000       NaN               8.0                   42
# 10         1011  45.000000   41534.0               6.0                   38
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df[['Work_Hours_Per_Week', 'Age']] = scaler.fit_transform(df[['Work_Hours_Per_Week', 'Age']])

# %%
df['Age'] = (df['Age'] - df['Age'].min()) / (df['Age'].max() - df['Age'].min())

# %%
from sklearn.preprocessing import StandardScaler

s_scaler = StandardScaler()

# %%
df[['Work_Hours_Per_Week']] = s_scaler.fit_transform(df[[ 'Work_Hours_Per_Week']])

# %%
df['Work_Hours_Per_Week']
# Out:
# 0    -0.905969
# 1     1.483629
# 2    -1.529343
# 3    -1.529343
# 4     0.964151
# 5     1.171942
# 6     1.483629
# 7     0.964151
# 8     0.444673
# 9    -0.282596
# 10   -0.698178
# 11   -1.321551
# 12   -0.905969
# 13   -1.009865
# 14   -0.802074
# 15    1.171942
# 16   -0.698178
# 17    1.483629
# 18   -1.113760
# 19   -1.529343
# 20    0.340777
# 21   -0.594283
# 22   -0.386491
# 23    0.860255
# 24   -0.074805
# 25    1.171942
# 26    0.652464
# 27    0.860255
# 28   -0.698178
# 29    0.444673
# 30    0.132986
# 31    1.483629
# 32    0.132986
# 33    1.068046
# 34    0.444673
# 35   -0.386491
# 36    1.483629
# 37   -0.905969
# 38   -1.425447
# 39   -1.321551
# 40    0.132986
# 41   -1.113760
# 42    0.132986
# 43    0.860255
# 44    0.132986
# 45    1.171942
# 46    0.132986
# 47   -1.425447
# 48   -1.425447
# 49    1.275837
# Name: Work_Hours_Per_Week, dtype: float64

# %%
df[''] = (df['Job_Satisfaction'] - df['Job_Satisfaction'].mean()) / df['Job_Satisfaction'].std()

# %%
df
# Out:
#     Employee_ID       Age    Salary  Job_Satisfaction  Work_Hours_Per_Week  \
# 0          1001  0.750000  108953.0               9.0            -0.905969
# 1          1002  0.361111   82995.0               8.0             1.483629
# 2          1003  0.166667   70757.0               2.0            -1.529343
# 3          1004  0.527778   39692.0               1.0            -1.529343
# 4          1005  0.472222   75758.0               7.0             0.964151
# 5          1006  0.583333  102409.0               7.0             1.171942
# 6          1007  0.250000       NaN               NaN             1.483629
# 7          1008  0.250000   95697.0               5.0             0.964151
# 8          1009  0.611111   67065.0               3.0             0.444673
# 9          1010  0.944444       NaN               8.0            -0.282596
# 10         1011  0.611111   41534.0               6.0            -0.698178
# ...
